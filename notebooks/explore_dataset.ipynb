# %%
import os
os.chdir("../")

# %%
import pandas as pd

movies = pd.read_csv('data/cleaned_movies_metadata.csv', low_memory=False)
ratings = pd.read_csv('data/cleaned_ratings_small.csv')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45436 entries, 0 to 45435
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   adult                 45436 non-null  object
#  1   budget                45436 non-null  float64
#  2   genres                45436 non-null  object
#  3   id                    45436 non-null  object
#  4   imdb_id               45419 non-null  object
#  5   original_language     45425 non-null  object
#  6   original_title        45436 non-null  object
#  7   popularity            45431 non-null  object
#  8   production_companies  45436 non-null  object
#  9   production_countries  45436 non-null  object
#  10  release_date          45346 non-null  object
#  11  revenue               45436 non-null  float64
#  12  runtime               45436 non-null  float64
#  13  spoken_languages      45436 non-null  object
#  14  status                45349 non-null  object
# ...

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100004 entries, 0 to 100003
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     100004 non-null  int64
#  1   movieId    100004 non-null  int64
#  2   rating     100004 non-null  float64
#  3   timestamp  100004 non-null  int64
# dtypes: float64(1), int64(3)
# memory usage: 3.1 MB

# %%
# Quick view of the data
print("Movies")
movies.head()
# print("Ratings")
# ratings.head()
# Out:
# Movies
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
# Basic statistics
print(movies.describe())
print(ratings.describe())
